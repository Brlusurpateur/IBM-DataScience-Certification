# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Submit Your Work and Grade Your Peers

# %% [markdown]
# This is a final exam of the IBM Data scientist program on coursera part "Tools for data science"

# %% [markdown]
# This is a list of data science languages: Python, R, SQL, Scala, Java, C++, julia, Java Script, php, GO, Ruby, Visual Basic.

# %% [markdown]
# This is a list of data science libraries uses by languages:
# - Python: Panda, Numpy, Matplotlib, Seaborn, Scikit-learn, Keras, TensorFlow, PyTorch.
# - Scala libraries: Vegas, BigDL.
# - R: ggplot2, Keras, TensoeFLow.

# %% [markdown]
# This is a list of data science tools:
